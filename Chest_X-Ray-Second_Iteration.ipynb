# %%
import os
import random
import math
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
import pandas as pd
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.

# %%
base_dir = '/home/ubuntu/kaggle/flowers/xray_images/Data/'
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

# %%
"""
HyperParameters:
- Learning Rate 
- Momentum 
- Number of Conv Blocks
- Number of Layers in Each Block 
- Parameters of each Layer (Conv, Pooling, Flatten, Dense)
- Regularization 
- Batch Normalization 

"""
# Out:
# '\nHyperParameters:\n- Learning Rate \n- Momentum \n- Number of Conv Blocks\n- Number of Layers in Each Block \n- Parameters of each Layer (Conv, Pooling, Flatten, Dense)\n- Regularization \n- Batch Normalization \n\n'

# %%
def Conv2D_Input(filters, kernel_size, strides, padding, activation, kernel_regularizer, name, input_shape):
    return tf.keras.layers.Conv2D(filters = filters, kernel_size = kernel_size, 
                                  strides = strides, padding = padding, activation = activation, 
                                  kernel_regularizer = kernel_regularizer, name = name, 
                                  input_shape = input_shape)


def Conv2D(filters, kernel_size, strides, padding, activation, kernel_regularizer, name):
    return tf.keras.layers.Conv2D(filters = filters, kernel_size = kernel_size, 
                                  strides = strides, padding = padding, activation = activation, 
                                  kernel_regularizer = kernel_regularizer, name = name)

def MaxPool(pool_size, strides, padding, name):
    return tf.keras.layers.MaxPooling2D(pool_size = pool_size, strides = strides, 
                                        padding = padding, name = name)

def Flatten(name):
    return tf.keras.layers.Flatten(name = name)

def Dense(units, activation, kernel_regularizer, name):
    return tf.keras.layers.Dense(units = units, activation = activation, 
                                 kernel_regularizer=kernel_regularizer,name = name)

def Batch_Normalize():
    return tf.keras.layers.BatchNormalization(axis=1)

def DropOut(dropout_rate):
    return tf.keras.layers.Dropout(dropout_rate)

# %%
# Note - To be convereted to functions before posting
def set_hyperparameters(param):
    
    LR_10P_Range = param['LR_10P_Range'] 
    Mtm_Val = param['Mtm_Val'] 
    BS_Val = param['BS_Val']  
    Cv_Bks_Val= param['Cv_Bks_Val']  
    Cv_CvLy_Val= param['Cv_CvLy_Val']  
    Cv_PoLy_Val = param['Cv_PoLy_Val'] 
    Cv_KS_Val = param['Cv_KS_Val']  
    Cv_Reg_Val = param['Cv_Reg_Val']
    Cv_Fil_Val = param['Cv_Fil_Val']  
    Cv_Pd_Val = param['Cv_Pd_Val']  
    Cv_Sd_Val = param['Cv_Sd_Val']  
    Cv_Av_Val = param['Cv_Av_Val']  
    Po_PS_Val = param['Po_PS_Val'] 
    Po_Pd_Val = param['Po_Pd_Val'] 
    Dl_Num_Val = param['Dl_Num_Val']  
    Dl_Unt_Val = param['Dl_Unt_Val']  
    Dl_Reg_Val = param['Dl_Reg_Val']  
    Dl_Reg_Val = param['Dl_Reg_Val'] 
    Bch_Norm_Val = param['Bch_Norm_Val']  
    Dpout_Val = param['Dpout_Val']  
    Dp_Rate = param['Dp_Rate']
    Opt_Algo_Val= param['Opt_Algo_Val']  
    Input_Shape = param['Input_Shape']
    

    LR = pow(10,random.uniform(LR_10P_Range[0],LR_10P_Range[1]))
    
    random.shuffle(Mtm_Val)
    Mtm = Mtm_Val[0]
    
    random.shuffle(BS_Val)
    BS = BS_Val[0]
    
    random.shuffle(Cv_Bks_Val)
    Cv_Bks = Cv_Bks_Val[0]
    
    Cv_CvLy = []
    Cv_KS = []
    Cv_Reg = []
    Po_PS = []
    Po_Sd = []

    random.shuffle(Cv_KS_Val)
    random.shuffle(Cv_Reg_Val)
    random.shuffle(Po_PS_Val)
    random.shuffle(Cv_CvLy_Val)
    
    for i in range(Cv_Bks):
        Cv_CvLy.append(Cv_CvLy_Val[0])
        Cv_KS.append(Cv_KS_Val[0])
        Cv_Reg.append(Cv_Reg_Val[0])
        Po_PS.append(Po_PS_Val[0])
        Po_Sd.append(Po_PS_Val[0])

    Cv_Fil = []    
    random.shuffle(Cv_Fil_Val)

    for i in range(Cv_Bks):
        Cv_Fil.append(Cv_Fil_Val[0]*pow(2,math.ceil((i+1)/2)-1))  
        
    Cv_Pd = []
    Cv_Sd = []
    Cv_Av = []
    Cv_PoLy = []
    Po_Pd = []

    for i in range(Cv_Bks):
        Cv_Pd.append(Cv_Pd_Val)
        Cv_Sd.append(Cv_Sd_Val)
        Cv_Av.append(Cv_Av_Val)
        Cv_PoLy.append(Cv_PoLy_Val)
        Po_Pd.append(Po_Pd_Val)
    
    random.shuffle(Dl_Num_Val)
    Dl_Num = Dl_Num_Val[0]
    
    Dl_Unt =[]

    for i in range(Dl_Num):
        random.shuffle(Dl_Unt_Val)
        Dl_Unt.append(Dl_Unt_Val[0])
        
    Dl_Reg = []
    random.shuffle(Dl_Reg_Val)

    for i in range(Dl_Num):
        Dl_Reg.append(Dl_Reg_Val[0])
    
    Dl_Av = []

    for i in range(Dl_Num):
        Dl_Av.append(Dl_Av_Val)

    random.shuffle(Bch_Norm_Val)
    Bch_Norm = Bch_Norm_Val[0]
    
    random.shuffle(Dpout_Val)
    Dpout = Dpout_Val[0]
    
    random.shuffle(Opt_Algo_Val)
    Opt_Algo = Opt_Algo_Val[0]
    
    hyperparams = {'LR':LR, 'Mtm':Mtm, 'BS':BS,
                    'Cv_Bks':Cv_Bks, 'Cv_CvLy':Cv_CvLy, 'Cv_PoLy':Cv_PoLy, 
                    'Cv_KS':Cv_KS, 'Cv_Reg':Cv_Reg, 'Cv_Fil':Cv_Fil, 
                    'Cv_Pd':Cv_Pd, 'Cv_Sd':Cv_Sd, 'Cv_Av':Cv_Av, 
                    'Po_PS':Po_PS, 'Po_Pd':Po_Pd, 'Po_Sd':Po_Sd,
                    'Dl_Num':Dl_Num,'Dl_Unt':Dl_Unt, 'Dl_Reg':Dl_Reg, 'Dl_Av':Dl_Av, 
                    'Bch_Norm':Bch_Norm, 'Dpout':Dpout, 'Dp_Rate':Dp_Rate,
                    'Opt_Algo':Opt_Algo, 'Input_Shape':Input_Shape}
    
    return hyperparams

# %%
def generate_model(hyperparams):
    
    Cv_Bks  = hyperparams['Cv_Bks']
    Cv_CvLy = hyperparams['Cv_CvLy']
    Cv_PoLy = hyperparams['Cv_PoLy']
    Cv_KS = hyperparams['Cv_KS']
    Cv_Reg = hyperparams['Cv_Reg']
    Cv_Fil = hyperparams['Cv_Fil']
    Cv_Pd = hyperparams['Cv_Pd']
    Cv_Sd = hyperparams['Cv_Sd']
    Cv_Av = hyperparams['Cv_Av']
    Po_PS = hyperparams['Po_PS']
    Po_Pd = hyperparams['Po_Pd']
    Po_Sd = hyperparams['Po_Sd']
    Dl_Num = hyperparams['Dl_Num']
    Dl_Unt = hyperparams['Dl_Unt']
    Dl_Reg = hyperparams['Dl_Reg']
    Dl_Av = hyperparams['Dl_Av']
    Bch_Norm = hyperparams['Bch_Norm']
    Dpout = hyperparams['Dpout']
    Dp_Rate = hyperparams['Dp_Rate']
    
    Model = tf.keras.Sequential()
    
    for i in range(Cv_Bks):

        Cv_Bk_Name = 'Blk' + str(i+1)

        for j in range(Cv_CvLy[i]):
            if (i==0 and j==0):
                
                Ly_Name = Cv_Bk_Name + '_Conv' + str(j+1)
                Ly = Conv2D_Input(Cv_Fil[i], Cv_KS[i],
                                  Cv_Sd[i], Cv_Pd[i],
                                  Cv_Av[i], Cv_Reg[i],                         
                                  Ly_Name, Input_Shape)
                Model.add(Ly)

                if Bch_Norm == 'conv' or Bch_Norm == 'all':
                    Ly = Batch_Normalize()
                    Model.add(Ly)

                if Dpout == 'conv' or Dpout == 'all':
                    Ly = DropOut(Dp_Rate)
                    Model.add(Ly)

            else:
     

                Ly_Name = Cv_Bk_Name + '_Conv' + str(j+1)
                Ly = Conv2D(Cv_Fil[i], Cv_KS[i],
                            Cv_Sd[i], Cv_Pd[i],
                            Cv_Av[i], Cv_Reg[i],                         
                            Ly_Name)
                Model.add(Ly)
            
                if Bch_Norm == 'conv' or Bch_Norm == 'all':
                    Ly = Batch_Normalize()
                    Model.add(Ly)

                if Dpout == 'conv' or Dpout == 'all':
                    Ly = DropOut(Dp_Rate)
                    Model.add(Ly)

        for k in range(Cv_PoLy[i]):

            Ly_Name = Cv_Bk_Name + '_Pool' + str(k+1)
            Ly = MaxPool(Po_PS[i], Po_Sd[i],
                         Po_Pd[i], Ly_Name)
            Model.add(Ly)
        
    Model.add(Flatten('Flatten'))

    for l in range(Dl_Num):
        
        Ly_Name = 'Dense' + str(l+1)

        Ly = Dense(Dl_Unt[l], Dl_Av[l], Dl_Reg[l], Ly_Name)
        Model.add(Ly)

        if Bch_Norm == 'dense' or Bch_Norm == 'all':
            Ly = Batch_Normalize()
            Model.add(Ly)

        if Dpout == 'dense' or Dpout == 'all':
            Ly = DropOut(Dp_Rate)
            Model.add(Ly)

    Model.add(Dense(1, 'sigmoid', None, 'Output'))
    
    return Model

# %%
def prepare_callbacks(es_patience):
    callback_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=es_patience,
                                                               verbose=1, restore_best_weights=True)
    #callback_model= ModelCheckpoint(filepath='/home/ubuntu/kaggle/flowers/xray_images/Outputs/Best_Model', 
                                    #save_best_only=True, save_weights_only=True)
    callbacks = [callback_early_stopping] #, callback_model]
    return callbacks

# %%
def compile_and_run_model(Model, Opt_Algo, LR, Mtm, Loss, Metrics):
    
    if Opt_Algo == 'sgd':
        Optimizer = tf.keras.optimizers.SGD(LR, Mtm)
        Model.compile(optimizer = Optimizer, loss = Loss, metrics = Metrics)
    
    elif Opt_Algo == 'adam':
        Optimizer = tf.keras.optimizers.Adam(learning_rate = LR)
        Model.compile(optimizer = Optimizer, loss = Loss, metrics = Metrics)

# %%
def prepare_train_test_data(train_dir, test_dir, batch_size, input_size):
    
    train_datagen = ImageDataGenerator(rescale=1.0/255.)
    test_datagen = ImageDataGenerator(rescale=1.0/255.)
    
    train_gen = train_datagen.flow_from_directory(train_dir,batch_size=batch_size,color_mode= 'rgb',
                                                    class_mode='binary',target_size=input_size) 
    test_gen = test_datagen.flow_from_directory(test_dir,batch_size=batch_size,color_mode= 'rgb',
                                                    class_mode='binary',target_size=input_size)
    
    return train_gen, test_gen

# %%
def export_results(iter_number, history, hyperparams, File_Name1, File_Name2):
    
    file = open(File_Name1,"w")
    file.write(str(hyperparams))
    file.close()
    
    df = pd.DataFrame.from_dict(history.history.items())
    
    df0 = pd.DataFrame()
    for i in range(7):
        df1 = pd.DataFrame(df[1][i],columns = [df[0][i]])
        df0 = pd.concat([df0, df1], axis=1)
    df0.to_csv(File_Name2)
    
    print("Files for iteration number "+ str(iter_number) + " have been exported.")

# %%
Input_Shape = (224,224,3) 
Input_Shape_WO_Channel = (224,224) 
Loss = 'binary_crossentropy'
Metrics = ['accuracy','Precision','Recall']

# %%
L2 = tf.keras.regularizers.l2(0.005)
Dp_Rate = 0.5

# %%
LR_10P_Range = [-2.8,-2.8]

# %%
LR = pow(10,random.uniform(LR_10P_Range[0],LR_10P_Range[1]))

# %%
Filters = [8,16]
Units = [128,512]

for i in Filters:
    for j in Units:
        print(i)
        print(j)
# Out:
# 8
# 128
# 8
# 512
# 16
# 128
# 16
# 512

# %%
LR_10P_Range = [-2.8,-2.8] # Learning Rate 
Mtm_Val = [0] # Momentum 
BS_Val = [64] # Batch Size

Cv_Bks_Val = [5] # Number of Conv Blocks
Cv_CvLy_Val = [1] # Num of Conv Layers by Conv Blocks (Can be different in each Conv Block)
Cv_PoLy_Val = 1 # Num of Pooling layers by Conv Blocks (Same by each Conv Block)

Cv_KS_Val = [3] # Kernerl Size in Conv Layers by Conv Blocks (Same across all Conv Blocks) 
Cv_Reg_Val = [None] # Regularizaion Type in Conv Layers by Conv Blocks (Same across all Conv Blocks)
Cv_Fil_Val = [8] # Number of Filters in Conv Layers by Conv Blocks (This fixes the first, rest are followed a-a-2a-2a-4a)
Cv_Pd_Val = 'same'
Cv_Sd_Val = (1,1)
Cv_Av_Val = 'relu'

Po_PS_Val = [(2,2)] # Pool Size in Pool Layers by Conv Blocks 
Po_Pd_Val = 'same'

Dl_Num_Val = [1]
Dl_Unt_Val = [128]
Dl_Reg_Val = [None]
Dl_Av_Val = 'relu'

Bch_Norm_Val = ['none']
Dpout_Val = ['none']
Opt_Algo_Val = ['sgd']

param_values = {'LR_10P_Range':LR_10P_Range, 'Mtm_Val':Mtm_Val, 'BS_Val':BS_Val,
                'Cv_Bks_Val':Cv_Bks_Val, 'Cv_CvLy_Val':Cv_CvLy_Val, 'Cv_PoLy_Val':Cv_PoLy_Val, 
                'Cv_KS_Val':Cv_KS_Val, 'Cv_Reg_Val':Cv_Reg_Val, 
                'Cv_Fil_Val':Cv_Fil_Val, 'Cv_Pd_Val':Cv_Pd_Val, 
                'Cv_Sd_Val':Cv_Sd_Val, 'Cv_Av_Val':Cv_Av_Val, 
                'Po_PS_Val':Po_PS_Val, 'Po_Pd_Val':Po_Pd_Val, 
                'Dl_Num_Val':Dl_Num_Val, 'Dl_Unt_Val':Dl_Unt_Val,
                'Dl_Reg_Val':Dl_Reg_Val, 'Dl_Av_Val':Dl_Av_Val, 
                'Bch_Norm_Val':Bch_Norm_Val, 'Dpout_Val':Dpout_Val,
                'Dp_Rate':Dp_Rate, 'Opt_Algo_Val':Opt_Algo_Val,
                'Input_Shape':Input_Shape}

# %%
os.chdir('/home/ubuntu/kaggle/flowers/xray_images/Output_Iter2')

# %%
for i in range(1):
    
    hyperparams = set_hyperparameters(param_values)
    Model = generate_model(hyperparams)
    
    Model.summary()

    print("")
    print("Batch_Size: "+str(hyperparams['BS']))
    print("Learning_Rate: "+str(hyperparams['LR']))
    print("Momentum: "+str(hyperparams['Mtm']))
    print("Optimization_Algo: "+str(hyperparams['Opt_Algo']))
    print("Regularization_Cv_Layers" + str(hyperparams['Cv_Reg']))
    print("Regularization_Dense_Layers" + str(hyperparams['Dl_Reg']))
    print ()
    print("")

    train_gen, test_gen = prepare_train_test_data(train_dir, test_dir, 
                                                      hyperparams['BS'], Input_Shape_WO_Channel)
    compile_and_run_model(Model, hyperparams['Opt_Algo'], hyperparams['LR'], hyperparams['Mtm'],
                              Loss, Metrics)
    callbacks = prepare_callbacks(10)
    
    history = Model.fit(train_gen, validation_data= test_gen,
                            epochs = 30, verbose=1, callbacks = callbacks)
    
    File_Name1 = 'Hyperparams_Model_' + str(i) + '.txt'
    File_Name2 = 'Model_Results_' + str(i) + '.csv'
    
    export_results(i, history, hyperparams, File_Name1, File_Name2)
    del(Model, history, train_gen, test_gen, hyperparams)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Blk1_Conv1 (Conv2D)          (None, 224, 224, 16)      448
# _________________________________________________________________
# Blk1_Conv2 (Conv2D)          (None, 224, 224, 16)      2320
# _________________________________________________________________
# Blk1_Pool1 (MaxPooling2D)    (None, 112, 112, 16)      0
# _________________________________________________________________
# Blk2_Conv1 (Conv2D)          (None, 112, 112, 16)      2320
# _________________________________________________________________
# Blk2_Conv2 (Conv2D)          (None, 112, 112, 16)      2320
# _________________________________________________________________
# Blk2_Pool1 (MaxPooling2D)    (None, 56, 56, 16)        0
# _________________________________________________________________
# Blk3_Conv1 (Conv2D)          (None, 56, 56, 32)        4640
# _________________________________________________________________
# Blk3_Conv2 (Conv2D)          (None, 56, 56, 32)        9248
# _________________________________________________________________
# Blk3_Pool1 (MaxPooling2D)    (None, 28, 28, 32)        0
# _________________________________________________________________
# Blk4_Conv1 (Conv2D)          (None, 28, 28, 32)        9248
# _________________________________________________________________
# Blk4_Conv2 (Conv2D)          (None, 28, 28, 32)        9248
# _________________________________________________________________
# Blk4_Pool1 (MaxPooling2D)    (None, 14, 14, 32)        0
# _________________________________________________________________
# Flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# Dense1 (Dense)               (None, 1024)              6423552
# _________________________________________________________________
# Output (Dense)               (None, 1)                 1025
# =================================================================
# Total params: 6,464,369
# Trainable params: 6,464,369
# Non-trainable params: 0
# _________________________________________________________________
#
# Batch_Size: 16
# Learning_Rate: 0.0013709531664719465
# Momentum: 0
# Optimization_Algo: sgd
# Regularization_Cv_Layers[None, None, None, None]
# Regularization_Dense_Layers[None]
#
#
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/30
# 325/326 [============================>.] - ETA: 0s - loss: 0.6594 - acc: 0.7317 - precision_16: 0.7446 - recall_16: 0.9731Epoch 1/30
# 326/326 [==============================] - 56s 171ms/step - loss: 0.6596 - acc: 0.7310 - precision_16: 0.7438 - recall_16: 0.9732 - val_loss: 0.6632 - val_acc: 0.6250 - val_precision_16: 0.6250 - val_recall_16: 1.0000
# Epoch 2/30
# 325/326 [============================>.] - ETA: 0s - loss: 0.5827 - acc: 0.7429 - precision_16: 0.7429 - recall_16: 1.0000Epoch 1/30
# 326/326 [==============================] - 54s 166ms/step - loss: 0.5826 - acc: 0.7429 - precision_16: 0.7429 - recall_16: 1.0000 - val_loss: 0.6895 - val_acc: 0.6250 - val_precision_16: 0.6250 - val_recall_16: 1.0000
# Epoch 3/30
# 325/326 [============================>.] - ETA: 0s - loss: 0.5705 - acc: 0.7429 - precision_16: 0.7429 - recall_16: 1.0000Epoch 1/30
# 326/326 [==============================] - 54s 167ms/step - loss: 0.5705 - acc: 0.7429 - precision_16: 0.7429 - recall_16: 1.0000 - val_loss: 0.6975 - val_acc: 0.6250 - val_precision_16: 0.6250 - val_recall_16: 1.0000
# Epoch 4/30
# 325/326 [============================>.] - ETA: 0s - loss: 0
30
# 162/163 [============================>.] - ETA: 0s - loss: 0.5684 - acc: 0.7434 - precision_18: 0.7434 - recall_18: 1.0000Epoch 1/30
#  20/163 [==>...........................] - ETA: 36s - loss: 0.6962 - acc: 0.6250 - precision_18: 0.6250 - recall_18: 1.0000Restoring model weights from the end of the best epoch.
# 163/163 [==============================] - 52s 321ms/step - loss: 0.5689 - acc: 0.7429 - precision_18: 0.7429 - recall_18: 1.0000 - val_loss: 0.6962 - val_acc: 0.6250 - val_precision_18: 0.6250 - val_recall_18: 1.0000
# Epoch 00006: early stopping
# Files for iteration number 1 have been exported.
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Blk1_Conv1 (Conv2D)          (None, 224, 224, 8)       224
# _________________________________________________________________
# Blk1_Conv2 (Conv2D)          (None, 224, 224, 8)       584
# _________________________________________________________________
# Blk1_Pool1 (MaxPooling2D)    (None, 112, 112, 8)       0
# _________________________________________________________________
# Blk2_Conv1 (Conv2D)          (None, 112, 112, 8)       584
# _________________________________________________________________
# Blk2_Conv2 (Conv2D)          (None, 112, 112, 8)       584
# _________________________________________________________________
# Blk2_Pool1 (MaxPooling2D)    (None, 56, 56, 8)         0
# _________________________________________________________________
# Blk3_Conv1 (Conv2D)          (None, 56, 56, 16)        1168
# _________________________________________________________________
# Blk3_Conv2 (Conv2D)          (None, 56, 56, 16)        2320
# _________________________________________________________________
# Blk3_Pool1 (MaxPooling2D)    (None, 28, 28, 16)        0
# _________________________________________________________________
# Blk4_Conv1 (Conv2D)          (None, 28, 28, 16)        2320
# _________________________________________________________________
# Blk4_Conv2 (Conv2D)          (None, 28, 28, 16)        2320
# _________________________________________________________________
# Blk4_Pool1 (MaxPooling2D)    (None, 14, 14, 16)        0
# _________________________________________________________________
# Flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# Dense1 (Dense)               (None, 1024)              3212288
# _________________________________________________________________
# Output (Dense)               (None, 1)                 1025
# =================================================================
# Total params: 3,223,417
# Trainable params: 3,223,417
# Non-trainable params: 0
# _________________________________________________________________
#
# Batch_Size: 128
# Learning_Rate: 0.0043088290308339
# Momentum: 0
# Optimization_Algo: adam
# Regularization_Cv_Layers[None, None, None, None]
# Regularization_Dense_Layers[None]
#
#
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/30
# 40/41 [============================>.] - ETA: 1s - loss: 0.5976 - acc: 0.7296 - precision_20: 0.7425 - recall_20: 0.9738Epoch 1/30
# 41/41 [==============================] - 57s 1s/step - loss: 0.5973 - acc: 0.7295 - precision_20: 0.7421 - recall_20: 0.9745 - val_loss: 0.6910 - val_acc: 0.6250 - val_precision_20: 0.6250 - val_recall_20: 1.0000
# Epoch 2/30
# 40/41 [============================>.] - ETA: 1s - loss: 0.5728 - acc: 0.7419 - precision_20: 0.7419 - recall_20: 1.0000Epoch 1/30
# 41/41 [==============================] - 53s 1s/step - loss: 0.5717 - acc: 0.7429 - precision_20: 0.7429 - recall_20: 1.0000 - val_loss: 0.6876 - val_acc: 0.6250 - val_precision_20: 0.6250 - val_recall_20: 1.0000
# Epoch 3/30
# 40/41 [============================>.] - ETA: 1s - loss: 0.3491 - acc: 0.8394 - precision_20: 0.8834 - recall_20: 0.9037Epoch 1/30
# 41/41 [==============================] - 53s 1s/step - loss: 0.3473 - acc: 0.8390 - precision_20: 0.8835 - recall_20: 0.9022 - val_loss: 0.8778 - val_acc: 0.7692 - val_precision_20: 0.7584 - val_recall_20: 0.9256
# Epoch 4/30
# 40/41 [============================>.] - ETA: 1s - loss: 0.2300 - acc: 0.8960 - precision_20: 0.9561 - recall_20: 0.9012Epoch 1/30
# 41/41 [==============================] - 53s 1s/step - loss: 0.2284 - acc: 0.8974 - precision_20: 0.9568 - recall_20: 0.9027 - val_loss: 1.1041 - val_acc: 0.6490 - val_precision_20: 0.6413 - val_recall_20: 0.9949
# Epoch 5/30
# 40/41 [============================>.] - ETA: 1s - loss: 0.1812 - acc: 0.9204 - precision_20: 0.9560 - recall_20: 0.9360Epoch 1/30
# 41/41 [==============================] - 53s 1s/step - loss: 0.1798 - acc: 0.9210 - precision_20: 0.9555 - recall_20: 0.9373 - val_loss: 1.1338 - val_acc: 0.7292 - val_precision_20: 0.7043 - val_recall_20: 0.9769
# Epoch 6/30
# 40/41 [============================>.] - ETA: 1s - loss: 0.0980 - acc: 0.9662 - precision_20: 0.9780 - recall_20: 0.9765Epoch 1/30
#  5/41 [==>...........................] - ETA: 38s - loss: 0.9789 - acc: 0.7804 - precision_20: 0.7535 - recall_20: 0.9641Restoring model weights from the end of the best epoch.
# 41/41 [==============================] - 54s 1s/step - loss: 0.0979 - acc: 0.9663 - precision_20: 0.9780 - recall_20: 0.9765 - val_loss: 0.9789 - val_acc: 0.7804 - val_precision_20: 0.7535 - val_recall_20: 0.9641
# Epoch 00006: early stopping
# Files for iteration number 2 have been exported.
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Blk1_Conv1 (Conv2D)          (None, 224, 224, 8)       224
# _________________________________________________________________
# Blk1_Conv2 (Conv2D)          (None, 224, 224, 8)       584
# _________________________________________________________________
# Blk1_Pool1 (MaxPooling2D)    (None, 112, 112, 8)       0
# _________________________________________________________________
# Blk2_Conv1 (Conv2D)          (None, 112, 112, 8)       584
# _________________________________________________________________
# Blk2_Conv2 (Conv2D)          (None, 112, 112, 8)       584
# _________________________________________________________________
# Blk2_Pool1 (MaxPooling2D)    (None, 56, 56, 8)         0
# _________________________________________________________________
# Blk3_Conv1 (Conv2D)          (None, 56, 56, 16)        1168
# _________________________________________________________________
# Blk3_Conv2 (Conv2D)          (None, 56, 56, 16)        2320
# _________________________________________________________________
# Blk3_Pool1 (MaxPooling2D)    (None, 28, 28, 16)        0
# _________________________________________________________________
# Blk4_Conv1 (Conv2D)          (None, 28, 28, 16)        2320
# _________________________________________________________________
# Blk4_Conv2 (Conv2D)          (None, 28, 28, 16)        2320
# _________________________________________________________________
# Blk4_Pool1 (MaxPooling2D)    (None, 14, 14, 16)        0
# _________________________________________________________________
# Blk5_Conv1 (Conv2D)          (None, 14, 14, 32)        4640
# _________________________________________________________________
# Blk5_Conv2 (Conv2D)          (None, 14, 14, 32)        9248
# _________________________________________________________________
# Blk5_Pool1 (MaxPooling2D)    (None, 7, 7, 32)          0
# _________________________________________________________________
# Flatten (Flatten)            (None, 1568)              0
# _________________________________________________________________
# Dense1 (Dense)               (None, 1024)              1606656
# _________________________________________________________________
# Output (Dense)               (None, 1)                 1025
# =================================================================
# Total params: 1,631,673
# Trainable params: 1,631,673
# Non-trainable params: 0
# _________________________________________________________________
#
# Batch_Size: 128
# Learning_Rate: 0.0020542251572056836
# Momentum: 0
# Optimization_Algo: sgd
# Regularization_Cv_Layers[None, None, None, None, None]
# Regularization_Dense_Layers[None]
#
#
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/30
# 40/41 [============================>.] - ETA: 1s - loss: 0.
#  5/41 [==>...........................] - ETA: 38s - loss: 0.8785 - acc: 0.6827 - precision_26: 0.6678 - recall_26: 0.9795Restoring model weights from the end of the best epoch.
# 41/41 [==============================] - 54s 1s/step - loss: 0.2225 - acc: 0.9005 - precision_26: 0.9572 - recall_26: 0.9066 - val_loss: 0.8785 - val_acc: 0.6827 - val_precision_26: 0.6678 - val_recall_26: 0.9795
# Epoch 00006: early stopping
# Files for iteration number 5 have been exported.
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Blk1_Conv1 (Conv2D)          (None, 224, 224, 8)       224
# _________________________________________________________________
# Blk1_Conv2 (Conv2D)          (None, 224, 224, 8)       584
# _________________________________________________________________
# Blk1_Pool1 (MaxPooling2D)    (None, 112, 112, 8)       0
# _________________________________________________________________
# Blk2_Conv1 (Conv2D)          (None, 112, 112, 8)       584
# _________________________________________________________________
# Blk2_Conv2 (Conv2D)          (None, 112, 112, 8)       584
# _________________________________________________________________
# Blk2_Pool1 (MaxPooling2D)    (None, 56, 56, 8)         0
# _________________________________________________________________
# Blk3_Conv1 (Conv2D)          (None, 56, 56, 16)        1168
# _________________________________________________________________
# Blk3_Conv2 (Conv2D)          (None, 56, 56, 16)        2320
# _________________________________________________________________
# Blk3_Pool1 (MaxPooling2D)    (None, 28, 28, 16)        0
# _________________________________________________________________
# Blk4_Conv1 (Conv2D)          (None, 28, 28, 16)        2320
# _________________________________________________________________
# Blk4_Conv2 (Conv2D)          (None, 28, 28, 16)        2320
# _________________________________________________________________
# Blk4_Pool1 (MaxPooling2D)    (None, 14, 14, 16)        0
# _________________________________________________________________
# Blk5_Conv1 (Conv2D)          (None, 14, 14, 32)        4640
# _________________________________________________________________
# Blk5_Conv2 (Conv2D)          (None, 14, 14, 32)        9248
# _________________________________________________________________
# Blk5_Pool1 (MaxPooling2D)    (None, 7, 7, 32)          0
# _________________________________________________________________
# Flatten (Flatten)            (None, 1568)              0
# _________________________________________________________________
# Dense1 (Dense)               (None, 512)               803328
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 827,833
# Trainable params: 827,833
# Non-trainable params: 0
# _________________________________________________________________
#
# Batch_Size: 32
# Learning_Rate: 0.001294345785909194
# Momentum: 0
# Optimization_Algo: sgd
# Regularization_Cv_Layers[None, None, None, None, None]
# Regularization_Dense_Layers[None]
#
#
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/30
# 162/163 [============================>.] - ETA: 0s - loss: 0.6771 - acc: 0.7319 - precision_28: 0.7433 - recall_28: 0.9761Epoch 1/30
# 163/163 [==============================] - 53s 325ms/step - loss: 0.6770 - acc: 0.7320 - precision_28: 0.7434 - recall_28: 0.9763 - val_loss: 0.6781 - val_acc: 0.6250 - val_precision_28: 0.6250 - val_recall_28: 1.0000
# Epoch 2/30
# 162/163 [============================>.] - ETA: 0s - loss: 0.6480 - acc: 0.7421 - precision_28: 0.7421 - recall_28: 1.0000Epoch 1/30
# 163/163 [==============================] - 52s 318ms/step - loss: 0.6477 - acc: 0.7429 - precision_28: 0.7429 - recall_28: 1.0000 - val_loss: 0.6668 - val_acc: 0.6250 - val_precision_28: 0.6250 - val_recall_28: 1.0000
# Epoch 3/30
# 162/163 [============================>.] - ETA: 0s - loss: 0.6174 - acc: 0.7427 - precision_28: 0.7427 - recall_28: 1.0000Epoch 1/30
# 163/163 [==============================] - 52s 318ms/step - loss: 0.6172 - acc: 0.7429 - precision_28: 0.7429 - recall_28: 1.0000 - val_loss: 0.6612 - val_acc: 0.6250 - val_precision_28: 0.6250 - val_recall_28: 1.0000
# Epoch 4/30
# 162/163 [============================>.] - ETA: 0s - loss: 0.5892 - acc: 0.7431 - precision_28: 0.7431 - recall_28: 1.0000Epoch 1/30
# 163/163 [==============================] - 52s 317ms/step - loss: 0.5893 - acc: 0.7429 - precision_28: 0.7429 - recall_28: 1.0000 - val_loss: 0.6690 - val_acc: 0.6250 - val_precision_28: 0.6250 - val_recall_28: 1.0000
# Epoch 5/30
# 162/163 [============================>.] - ETA: 0s - loss: 0.5753 - acc: 0.7427 - precision_28: 0.7427 - recall_28: 1.0000Epoch 1/30
# 163/163 [==============================] - 52s 319ms/step - loss: 0.5750 - acc: 0.7429 - precision_28: 0.7429 - recall_28: 1.0000 - val_loss: 0.6825 - val_acc: 0.6250 - val_precision_28: 0.6250 - val_recall_28: 1.0000
# Epoch 6/30
# 162/163 [============================>.] - ETA: 0s - loss: 0.5715 - acc: 0.7431 - precision_28: 0.7431 - recall_28: 1.0000Epoch 1/30
# 163/163 [==============================] - 52s 317ms/step - loss: 0.5717 - acc: 0.7429 - precision_28: 0.7429 - recall_28: 1.0000 - val_loss: 0.6902 - val_acc: 0.6250 - val_precision_28: 0.6250 - val_recall_28: 1.0000
# Epoch 7/30
# 162/163 [============================>.] - ETA: 0s - loss: 0.5707 - acc: 0.7432 - precision_28: 0.7432 - recall_28: 1.0000Epoch 1/30
#  20/163 [==>...........................] - ETA: 35s - loss: 0.6906 - acc: 0.6250 - precision_28: 0.6250 - recall_28: 1.0000Restoring model weights from the end of the best epoch.
# 163/163 [==============================] - 52s 321ms/step - loss: 0.5711 - acc: 0.7429 - precision_28: 0.7429 - recall_28: 1.0000 - val_loss: 0.6906 - val_acc: 0.6250 - val_precision_28: 0.6250 - val_recall_28: 1.0000
# Epoch 00007: early stopping
# Files for iteration number 6 have been exported.
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Blk1_Conv1 (Conv2D)          (None, 224, 224,
30
# 162/163 [============================>.] - ETA: 0s - loss: 0.1287 - acc: 0.9495 - precision_42: 0.9638 - recall_42: 0.9683Epoch 1/30
# 163/163 [==============================] - 52s 319ms/step - loss: 0.1287 - acc: 0.9494 - precision_42: 0.9638 - recall_42: 0.9683 - val_loss: 0.4655 - val_acc: 0.8029 - val_precision_42: 0.7686 - val_recall_42: 0.9795
# Epoch 17/30
# 162/163 [============================>.] - ETA: 0s - loss: 0.1163 - acc: 0.9547 - precision_42: 0.9679 - recall_42: 0.9712Epoch 1/30
# 163/163 [==============================] - 51s 315ms/step - loss: 0.1160 - acc: 0.9548 - precision_42: 0.9681 - recall_42: 0.9711 - val_loss: 0.7401 - val_acc: 0.7452 - val_precision_42: 0.7119 - val_recall_42: 0.9949
# Epoch 18/30
# 162/163 [============================>.] - ETA: 0s - loss: 0.1085 - acc: 0.9576 - precision_42: 0.9690 - recall_42: 0.9740Epoch 1/30
#  20/163 [==>...........................] - ETA: 35s - loss: 0.5768 - acc: 0.7885 - precision_42: 0.7529 - recall_42: 0.9846Restoring model weights from the end of the best epoch.
# 163/163 [==============================] - 52s 319ms/step - loss: 0.1081 - acc: 0.9578 - precision_42: 0.9692 - recall_42: 0.9742 - val_loss: 0.5768 - val_acc: 0.7885 - val_precision_42: 0.7529 - val_recall_42: 0.9846
# Epoch 00018: early stopping
# Files for iteration number 13 have been exported.
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Blk1_Conv1 (Conv2D)          (None, 224, 224, 16)      448
# _________________________________________________________________
# Blk1_Conv2 (Conv2D)          (None, 224, 224, 16)      2320
# _________________________________________________________________
# Blk1_Pool1 (MaxPooling2D)    (None, 112, 112, 16)      0
# _________________________________________________________________
# Blk2_Conv1 (Conv2D)          (None, 112, 112, 16)      2320
# _________________________________________________________________
# Blk2_Conv2 (Conv2D)          (None, 112, 112, 16)      2320
# _________________________________________________________________
# Blk2_Pool1 (MaxPooling2D)    (None, 56, 56, 16)        0
# _________________________________________________________________
# Blk3_Conv1 (Conv2D)          (None, 56, 56, 32)        4640
# _________________________________________________________________
# Blk3_Conv2 (Conv2D)          (None, 56, 56, 32)        9248
# _________________________________________________________________
# Blk3_Pool1 (MaxPooling2D)    (None, 28, 28, 32)        0
# _________________________________________________________________
# Blk4_Conv1 (Conv2D)          (None, 28, 28, 32)        9248
# _________________________________________________________________
# Blk4_Conv2 (Conv2D)          (None, 28, 28, 32)        9248
# _________________________________________________________________
# Blk4_Pool1 (MaxPooling2D)    (None, 14, 14, 32)        0
# _________________________________________________________________
# Blk5_Conv1 (Conv2D)          (None, 14, 14, 64)        18496
# _________________________________________________________________
# Blk5_Conv2 (Conv2D)          (None, 14, 14, 64)        36928
# _________________________________________________________________
# Blk5_Pool1 (MaxPooling2D)    (None, 7, 7, 64)          0
# _________________________________________________________________
# Flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# Dense1 (Dense)               (None, 1024)              3212288
# _________________________________________________________________
# Output (Dense)               (None, 1)                 1025
# =================================================================
# Total params: 3,308,529
# Trainable params: 3,308,529
# Non-trainable params: 0
# _________________________________________________________________
#
# Batch_Size: 64
# Learning_Rate: 0.006640788751586083
# Momentum: 0
# Optimization_Algo: adam
# Regularization_Cv_Layers[None, None, None, None, None]
# Regularization_Dense_Layers[None]
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/30
# 81/82 [============================>.] - ETA: 0s - loss: 0.8839 - acc: 0.7426 - precision_44: 0.7426 - recall_44: 1.0000Epoch 1/30
# 82/82 [==============================] - 57s 690ms/step - loss: 0.8799 - acc: 0.7429 - precision_44: 0.7429 - recall_44: 1.0000 - val_loss: 0.6894 - val_acc: 0.6250 - val_precision_44: 0.6250 - val_recall_44: 1.0000
# Epoch 2/30
# 81/82 [============================>.] - ETA: 0s - loss: 0.5741 - acc: 0.7426 - precision_44: 0.7426 - recall_44: 1.0000Epoch 1/30
# 82/82 [==============================] - 52s 640ms/step - loss: 0.5739 - acc: 0.7429 - precision_44: 0.7429 - recall_44: 1.0000 - val_loss: 0.6778 - val_acc: 0.6250 - val_precision_44: 0.6250 - val_recall_44: 1.0000
# Epoch 3/30
# 81/82 [============================>.] - ETA: 0s - loss: 0.5743 - acc: 0.7422 - precision_44: 0.7422 - recall_44: 1.0000Epoch 1/30
# 82/82 [==============================] - 53s 649ms/step - loss: 0.5736 - acc: 0.7429 - precision_44: 0.7429 - recall_44: 1.0000 - val_loss: 0.6897 - val_acc: 0.6250 - val_precision_44: 0.6250 - val_recall_44: 1.0000
# Epoch 4/30
# 81/82 [============================>.] - ETA: 0s - loss: 0.5716 - acc: 0.7420 - precision_44: 0.7420 - recall_44: 1.0000Epoch 1/30
# 82/82 [==============================] - 53s 651ms/step - loss: 0.5707 - acc: 0.7429 - precision_44: 0.7429 - recall_44: 1.0000 - val_loss: 0.7057 - val_acc: 0.6250 - val_precision_44: 0.6250 - val_recall_44: 1.0000
# Epoch 5/30
# 81/82 [============================>.] - ETA: 0s - loss: 0.5721 - acc: 0.7430 - precision_44: 0.7430 - recall_44: 1.0000Epoch 1/30
# 82/82 [==============================] - 53s 650ms/step - loss: 0.5722 - acc: 0.7429 - precision_44: 0.7429 - recall_44: 1.0000 - val_loss: 0.6844 - val_acc: 0.6250 - val_precision_44: 0.6250 - val_recall_44: 1.0000
# Epoch 6/30
# 81/82 [============================>.] - ETA: 0s - loss: 0.5698 - acc: 0.7436 - precision_44: 0.7436 - recall_44: 1.0000Epoch 1/30
# 10/82 [==>...........................] - ETA: 39s - loss: 0.6941 - acc: 0.6250 - precision_44: 0.6250 - recall_44: 1.0000Restoring model weights from the end of the best epoch.
# 82/82 [==============================] - 54s 661ms/step - loss: 0.5705 - acc: 0.7429 - precision_44: 0.7429 - recall_44: 1.0000 - val_loss: 0.6941 - val_acc: 0.6250 - val_precision_44: 0.6250 - val_recall_44: 1.0000
# Epoch 00006: early stopping
# Files for iteration number 14 have been exported.
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Blk1_Conv1 (Conv2D)          (None, 224, 224, 8)       224
# _________________________________________________________________
# Blk1_Conv2 (Conv2D)          (None, 224, 224, 8)       584
# _________________________________________________________________
# Blk1_Pool1 (MaxPooling2D)    (None, 112, 112, 8)       0
# _________________________________________________________________
# Blk2_Conv1 (Conv2D)          (None, 112, 112, 8)       584
# _________________________________________________________________
# Blk2_Conv2 (Conv2D)          (None, 112, 112, 8)       584
# _________________________________________________________________
# Blk2_Pool1 (MaxPooling2D)    (None, 56, 56, 8)         0
# _________________________________________________________________
# Blk3_Conv1 (Conv2D)          (None, 56, 56, 16)        1168
# _________________________________________________________________
# Blk3_Conv2 (Conv2D)          (None, 56, 56, 16)        2320
# _________________________________________________________________
# Blk3_Pool1 (MaxPooling2D)    (None, 28, 28, 16)        0
# _________________________________________________________________
# Blk4_Conv1 (Conv2D)          (None, 28, 28, 16)        2320
# _________________________________________________________________
# Blk4_Conv2 (Conv2D)          (None, 28, 28, 16)        2320
# _________________________________________________________________
# Blk4_Pool1 (MaxPooling2D)    (None, 14, 14, 16)        0
# _________________________________________________________________
# Flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# Dense1 (Dense)               (None, 256)               803072
# _________________________________________________________________
# Output (Dense)               (None, 1)                 257
# =================================================================
# Total params: 813,433
# Trainable params: 813,433
# Non-trainable params: 0
# _________________________________________________________________
#
# Batch_Size: 64
# Learning_Rate: 0.00364478896656295
# Momentum: 0
# Optimization_Algo: adam
# Regularization_Cv_Layers[None, None, None, None]
# Regularization_Dense_Layers[None]
#
#
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/30
# 81/82 [============================>.] - ETA: 0s - loss: 0.5946 - acc: 0.7438 - precision_46: 0.7441 - recall_46: 0.9992Epoch 1/30
# 82/82 [==============================] - 55s 667ms/step - loss: 0.5954 - acc: 0.7427 - precision_46: 0.7430 - recall_46: 0.9992 - val_loss: 0.6888 - val_acc: 0.6250 - val_precision_46: 0.6250 - val_recall_46: 1.0000
# Epoch 2/30
# 78/82 [===========================>..] - ETA: 2s - loss: 0.5721 - acc: 0.7427 - precision_46: 0.7427 - recall_46: 1.0000
